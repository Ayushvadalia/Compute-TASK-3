# %% [markdown]
# DATA LOADING AND EXPLORATION

# %%
import pandas as pd#importing pandas library

# %%
df=pd.read_csv('train.csv')#Loading the data in the dataframe named df

# %%
df.head(10)#displaying first few rows
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.isnull()#displaying all the missing values
#Where there is a missing value there will be written TRUE
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df.notnull()
#displaying all the missing values
#Where there is a missing value there will be written FALSE
# Out:
#      PassengerId  Survived  Pclass  Name   Sex    Age  SibSp  Parch  Ticket  \
# 0           True      True    True  True  True   True   True   True    True
# 1           True      True    True  True  True   True   True   True    True
# 2           True      True    True  True  True   True   True   True    True
# 3           True      True    True  True  True   True   True   True    True
# 4           True      True    True  True  True   True   True   True    True
# ..           ...       ...     ...   ...   ...    ...    ...    ...     ...
# 886         True      True    True  True  True   True   True   True    True
# 887         True      True    True  True  True   True   True   True    True
# 888         True      True    True  True  True  False   True   True    True
# 889         True      True    True  True  True   True   True   True    True
# 890         True      True    True  True  True   True   True   True    True
#
#      Fare  Cabin  Embarked
# 0    True  False      True
# ...

# %%
print(df.fillna(method ='pad'))
# fill in a null value with a previous value
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.dropna()
#deleting the rows having null values
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Hence droping the rows containing null values is reducing the maximum number of data so we will not use this method

# %%
print('Fill Missing Data\n', df.fillna(method ='bfill'))
#fill in a null value with a next value.
# Out:
# Fill Missing Data
#       PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
print(df['Cabin'].isna().sum())
#Counting the null values present in Cabin column
# Out:
# 687

# %% [markdown]
# As cabin column has major Null values we can delete that column

# %%
del df['Cabin']
#Deketing cabin column

# %%
print(df.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
df.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Now major rows are left hence we can further go with this data

# %%
df['Age'].describe()
#Statistics for Age column
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df['Fare'].describe()
#Statictics for Fare column
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %% [markdown]
# # DATA VISUALIZATION WITH MATPLOTLIB

# %% [markdown]
# ### BAR CHART

# %%
import matplotlib.pyplot as plt

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %% [markdown]
# HERE we came to know the counts of each class passengers

# %%
data={

  'Class':['1','2','3'],
  'Count':[216,184,491]

}
#Replacing with actual data by creating a new dataframe

fd=pd.DataFrame(data)
#Giving data to the dataframe

# %%
plt.bar(fd['Class'],fd['Count'])
plt.show()

# %%
plt.xlabel('Class')#Labelling x axis
plt.ylabel('Count')#Labelling y axis
plt.title('Count of passengers in each passenger class')
#Giving name of the title
plt.bar(fd['Class'],fd['Count'])
#Giving instuction to make a Bar chart
plt.show()
#Giving instruction to show

# %% [markdown]
# HISTOGRAM

# %%
df=pd.read_csv('train.csv')

# %%
df['Age'].value_counts()
df['Age'].max()#Finding the max value
# Out:
# 80.0

# %%
y=10,20,30,40,50,60,70,80

# %%
plt.xlabel('Age')
plt.ylabel('Count')
#Labelling x and y axis
plt.hist(df['Age'],y)
plt.show()

# %% [markdown]
# ## PIE CHART

# %%
df['Sex'].replace({'male': '1', 'female': '2'}, inplace=True)
#Replacing male as 1 and female as 2 for easy distribution

# %%
df['Sex'].value_counts()
#Counting there were how many male and female passengers
# Out:
# 1    577
# 2    314
# Name: Sex, dtype: int64

# %%
plt.title('Distribution of passengers')#Adding title to the graph
gender=["male","female"]#Labelling
slices=[577,314]#Distribution the pie chart on terms of this numbers
plt.pie(slices,labels=gender)
plt.show()#Displaying the graph

# %% [markdown]
# ## BOX PLOT

# %%
df['Fare'].max()
# Out:
# 512.3292

# %%
df['Fare'].value_counts()
# Out:
# 8.0500     43
# 13.0000    42
# 7.8958     38
# 7.7500     34
# 26.0000    31
#            ..
# 35.0000     1
# 28.5000     1
# 6.2375      1
# 14.0000     1
# 10.5167     1
# Name: Fare, Length: 248, dtype: int64

# %%
plt.boxplot(df['Fare'],notch=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7a07dfa580a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7a07dfa5b430>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7a07dfa58640>],
#  'medians': [<matplotlib.lines.Line2D at 0x7a07dfa5b9a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7a07dfa5bb20>],
#  'means': []}

# %% [markdown]
# # VISUALISATION WITH SEABORN

# %% [markdown]
# ## Heatmap

# %%
import seaborn as sns

# %%
print(df.head(20))
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name Sex   Age  SibSp  Parch  \
# 0                             Braund, Mr. Owen Harris   1  22.0      1      0
# ...

# %%
correlation_matrix=df.corr()
#to calculate the correlation between two or more numerical variables in a DataFrame.
# Out:
# <ipython-input-38-5c391a4d1649>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix=df.corr()

# %%
sns.heatmap(correlation_matrix)
# Out:
# <Axes: >

# %%
sns.heatmap(correlation_matrix,annot=True)
#annot True gives the values in between the box
# Out:
# <Axes: >

# %% [markdown]
# ## VIOLIN PLOT

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
# Sample DataFrame (replace this with your data)
data={'Age':[21,33,56,74,45,55,46,67,54,33,22,22],
'Pclass':[1,2,3,3,2,1,2,2,3,2,1,2]}

# %%
cd=pd.DataFrame(data)

# %%
sns.violinplot(x='Pclass', y='Age', data=cd)
#Making the violin plot
plt.title('Distribution of Ages by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# ## COUNT PLOT

# %%
df=pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
sns.countplot(df,x="Pclass")
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(df, x="Pclass", hue="Survived")
#The "hue" parameter allows you to add an additional
#dimension to the plot. Here, "survived" is specified as the "hue" variable.
#This means that the bars on the countplot will be grouped and colored
#by the "survived" column. It's often used to represent a
#categorical variable (in this case, whether a passenger survived or not)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %% [markdown]
# ## PAIR PLOT

# %%
sns.pairplot(df)

# %%
sns.pairplot(df, hue="Pclass", diag_kind="hist")

# %% [markdown]
# # Question to ans with plots

# %% [markdown]
# What is the distribution of passengers by class?

# %%
plt.figure(figsize=(8, 6))

sns.countplot(data=df, x="Pclass", palette="Set1")

plt.title('Distribution of Passengers by Class')
plt.xlabel('Passenger Class')
plt.ylabel('Number of Passengers')

plt.show()

# %% [markdown]
# What is the age distribution of passengers on the Titanic?

# %%
sns.violinplot(df,x="Age")
# Out:
# <Axes: xlabel='Age'>

# %% [markdown]
# What is the gender distribution among passengers?

# %%
sns.countplot(data=df, x="Sex",)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %% [markdown]
# How does fare vary on the Titanic?

# %%
#Fare vary on the basis of Class of passengengers
sns.barplot(x="Pclass",y="Fare",data=df)
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %% [markdown]
# Is there a correlation between different numerical features in the dataset?

# %%
correlation_matrix=df.corr()
sns.heatmap(correlation_matrix)
# Out:
# <ipython-input-92-97166da7d1c9>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix=df.corr()
# <Axes: >

# %% [markdown]
# How does age distribution vary by passenger class?

# %%
sns.violinplot(x="Pclass",y="Age",data=df)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# What is the survival rate for each passenger class?

# %%
sns.boxplot(x="Pclass",y="Survived",data=df)
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %% [markdown]
# Are there any interesting relationships between numerical features in the dataset?

# %%
plt.figure(figsize=(10,10))

sns.relplot(df)
